# %%
#팰린드롬 : true, 이외에 False
def solution(text):
    if text[::-1] == text:
        return True
    else:
        return False
    
solution("토마토")
# Out:
# True

# %%
a = ['123', '23','345']

# %%
a *= 100

# %% [markdown]
# sum([1, 2, 3])

# %%
sum(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20428\1838402321.py in <module>
# ----> 1 sum(a)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# %%time
sum(map(int, a))
# Out:
# Wall time: 1.99 ms
# 4910000

# %%
[int(x) for x in a]
# Out:
# [123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
#  23,
#  345,
#  123,
# ...

# %%
import requests
import bs4
from bs4 import BeautifulSoup as BS

# %%
import seaborn as sns
import matplotlib as plt
import numpy as np
import pandas as pd

# %%
bs4.Beautiful(text)
BeautifulSoup(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20428\2872555460.py in <module>
# ----> 1 bs4.Beautiful(text)
#       2 BeautifulSoup(text)
#
# AttributeError: module 'bs4' has no attribute 'Beautiful'

# %%
url = "https://finance.naver.com/item/sise_day.naver?code=035720&page1"

# %%
head = {
    "User-Agent": "mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/94.0.4606.71 safari/537.36 edg/94.0.992.38"
}

# %%
r = requests.get(url, headers=head)

# %%
r.status_code
# Out:
# 200

# %%
bs = BS(r.text)

# %%
r.text
# Out:
# '\n<html lang="ko">\n<head>\n<meta http-equiv="Content-Type" content="text/html; charset=euc-kr">\n<title>네이버 증권</title>\n\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230109162011/css/newstock.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230109162011/css/common.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230109162011/css/layout.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230109162011/css/main.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230109162011/css/newstock2.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230109162011/css/newstock3.css">\n<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/imgstock/static.pc/20230109162011/css/world.css">\n</head>\n<body>\n<scri
# ...

# %%
rt = bs.find("table", {'class' : "type2"})

# %%
a = 10

# %%
id(a)
# Out:
# 1812963486288

# %%
b = a

# %%
help = bs.find()

# %%
id(b)
# Out:
# 1812963486288

# %%
#2, 3, 4, 5, 6, 10, 11, 12, 13, 14
a = rt.findAll("tr")[14]

# %%
[x.text.strip().replace(",","") for x in a.findAll("td")]
# Out:
# ['', '', '', '', '', '', '']

# %%
result = [[x.text.strip().replace(",","") for x in rt.findAll("tr")[cnt].findAll("td")] for cnt in [2, 3, 4, 5, 6, 10, 11, 12, 13, 14]]

# %%
result = []
for cnt in [2, 3, 4, 5, 6, 10, 11, 12, 13, 14]:
    tmp = rt.findAll("tr")[cnt]
    result.append([x.text.strip().replace(",","") for x in tmp.findAll("td")])

# %%
result
# Out:
# [['', '', '0', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', ''],
#  ['', '', '', '', '', '', '']]

# %%
def get_stock(code, s_page, e_page):
    code = 
    
    return result

# %%
import pyautogui
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20428\4226049166.py in <module>
# ----> 1 import pyautogui
#
# ModuleNotFoundError: No module named 'pyautogui'

# %%
url = "https://finance.naver.com/item/sise_day.naver?code=035720&page1"
head = {
    "User-Agent": "mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/94.0.4606.71 safari/537.36 edg/94.0.992.38"
}
